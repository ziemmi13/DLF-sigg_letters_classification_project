# %% [markdown]
# ## DATASET LOOKUP

# %%
import os

DATASET_DIR = "./dataset/"
TRAIN_DIR = "asl_alphabet_train"
TEST_DIR = "asl_alphabet_test"

# %%
classes = os.listdir(os.path.join(DATASET_DIR, TRAIN_DIR))
print(classes)
len(classes)
# Out:
# ['W', 'space', 'del', 'F', 'nothing', 'V', 'Q', 'D', 'B', 'O', 'N', 'A', 'E', 'K', 'C', 'S', 'R', 'M', 'T', 'X', 'U', 'G', 'L', 'Y', 'I', 'J', 'H', 'P', 'Z']
# 29

# %%
from matplotlib import pyplot as plt
from PIL import Image

plt.figure(figsize=(10,8))
for i, _class in enumerate(classes):

    img_path = os.path.join(DATASET_DIR, TRAIN_DIR) + f"/{_class}/{_class}1.jpg"
    img = Image.open(img_path)
    plt.subplot(5, 6, i+1)
    plt.grid(False)
    plt.title(_class)
    plt.imshow(img)
    plt.axis('off') 

plt.tight_layout()
plt.show()

# %% [markdown]
# ## MEDIAPIPE TEST

# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# Inicjalizacja MediaPipe
mp_hands = mp.solutions.hands
mp_draw = mp.solutions.drawing_utils

def process_image(image_path):
    try:
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # Convert to RGB
        
        # Initialize the Hand Detector
        with mp_hands.Hands(
            static_image_mode=True, # Image - not a video
            max_num_hands=1,
            min_detection_confidence=0.5
            ) as hands:
            results = hands.process(image_rgb)
            
            # If a hand is detected draw points and lines on the oplot
            if results.multi_hand_landmarks:
                for hand_landmarks in results.multi_hand_landmarks:
                    # Rysowanie punktów i połączeń
                    mp_draw.draw_landmarks(
                        image_rgb,
                        hand_landmarks,
                        mp_hands.HAND_CONNECTIONS,
                        mp_draw.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=1),
                        mp_draw.DrawingSpec(color=(0, 0, 255), thickness=2)
                    )
                    
                    # Adding numbers to points
                    # for id, landmark in enumerate(hand_landmarks.landmark):
                    #     height, width, _ = image_rgb.shape
                    #     cx, cy = int(landmark.x * width), int(landmark.y * height)
                    #     cv2.putText(image_rgb, str(id), (cx, cy), 
                    #             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)
            
                return image_rgb
            
            else: return None
            
    
    except Exception as e:
        print(f"Error processing image: {image_path}: {str(e)}")
        return None

# %%
# Dataset mediapipe
plt.figure(figsize=(10, 100))
for idx, _class in enumerate(classes):
    
    img_path = os.path.join(DATASET_DIR, TRAIN_DIR) + f"/{_class}/{_class}1.jpg"
    # Oryginalny obraz
    original_img = Image.open(img_path)
    plt.subplot(29, 2, 2*idx+1)
    plt.title(_class)
    plt.imshow(original_img)
    plt.axis('off')
    
    # Obraz z wykrytymi punktami charakterystycznymi
    processed_img = process_image(img_path)
    plt.subplot(29, 2, 2*idx+2)

    if processed_img is not None:
        plt.title('Wykryte punkty charakterystyczne')
        plt.imshow(processed_img)
        plt.axis('off')
    else:
        plt.title('Nie wykryto punktów charakterystycznych')
        plt.imshow(original_img)
        plt.axis('off')

# plt.tight_layout()
plt.show()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736617015.563356  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617015.626025  188382 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1736617015.656710  188358 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617015.676955  188380 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617015.685936  188360 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# I0000 00:00:1736617015.715172  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617015.732927  188416 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617015.758828  188388 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617015.776220  188414 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617015.809875  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617015.825938  188450 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617015.853024  188420 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617015.870454  188449 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617015.896983  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617015.942666  188484 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617015.968803  188454 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617015.986291  188483 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617016.031383  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617016.076031  188518 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617016.102300  188489 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617016.119798  188491 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617016.146893  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617016.166667  188553 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617016.187733  188523 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617016.205116  188552 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617016.247950  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617016.292713  188587 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617016.300113  188558 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617016.315497  188559 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617016.349189  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617016.392617  188621 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617016.418603  188592 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617016.436212  188591 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617016.463661  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617016.492809  188655 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617016.500091  188625 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617016.517473  188629 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617016.550938  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617016.564132  188689 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617016.589775  188658 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617016.606989  188661 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617016.631106  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617016.649402  188723 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617016.665048  188693 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617016.677279  188695 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617016.702652  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617016.742775  188757 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617016.750070  188728 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617016.766991  188730 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617016.814224  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617016.829315  188791 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617016.836486  188763 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617016.842620  188762 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617016.881077  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617016.893751  188825 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617016.918576  188793 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617016.924784  188823 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617016.966180  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617016.983528  188859 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617016.998607  188831 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617017.004274  188827 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617017.034363  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617017.048845  188893 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617017.055816  188864 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617017.072025  188866 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617017.104057  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617017.116829  188927 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617017.123696  188899 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617017.139095  188925 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617017.231495  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617017.250518  188962 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617017.265534  188933 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617017.271570  188960 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617017.300051  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617017.313222  188996 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617017.320016  188967 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617017.334851  188973 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617017.367079  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617017.380055  189030 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617017.405033  189000 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617017.421866  189026 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617017.444959  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617017.459621  189064 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617017.474872  189035 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617017.481217  189033 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617017.510363  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617017.559432  189098 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617017.571831  189069 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617017.583851  189097 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617017.633028  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617017.676176  189132 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617017.691822  189103 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617017.697941  189131 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617017.763743  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617017.809356  189166 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617017.822835  189136 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617017.839288  189140 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617017.897714  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617017.942782  189200 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617017.968436  189170 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617017.975085  189168 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617018.014401  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617018.059302  189234 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617018.066614  189203 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617018.079015  189231 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617018.113834  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617018.126613  189268 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617018.140995  189236 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617018.147352  189265 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617018.175601  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617018.188617  189302 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617018.196417  189270 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617018.207989  189301 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617018.247607  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617018.292687  189341 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617018.317692  189313 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617018.323352  189337 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %% [markdown]
# Another test Image

# %%
# Test mediapipe
num_images = 6
labels = ["K", "A", "I", "S", "A"]

plt.figure(figsize=(10, 20))
for idx, label in enumerate(labels):
    img_path = DATASET_DIR + f"test_images/test_image#{idx+1}.png"
    # Oryginalny obraz
    original_img = Image.open(img_path)
    plt.subplot(num_images, 2, 2*idx+1)
    plt.title(label)
    plt.imshow(original_img)
    plt.axis('off')

    # Obraz z wykrytymi punktami charakterystycznymi
    processed_img = process_image(img_path)
    plt.subplot(num_images, 2, 2*idx+2)

    if processed_img is not None:
        plt.title('Wykryte punkty charakterystyczne')
        plt.imshow(processed_img)
        plt.axis('off')
    else:
        plt.title('Nie wykryto punktów charakterystycznych')
        plt.imshow(original_img)
        plt.axis('off')

plt.show()
# Out:
# I0000 00:00:1736617044.732510  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617044.753363  189466 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617044.769276  189437 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617044.775023  189465 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617044.845975  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617044.860241  189531 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617044.886234  189502 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617044.903722  189503 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617044.973710  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617045.026022  189565 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617045.051790  189534 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617045.069137  189563 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617045.147817  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617045.192707  189599 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617045.200340  189568 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617045.216409  189580 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1736617045.283251  188072 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1736617045.299586  189633 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1736617045.325343  189603 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736617045.342483  189632 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
